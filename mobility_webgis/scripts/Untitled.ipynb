# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(
    'postgresql+psycopg://postgres:postgres@db:5432/mobility'
)

pd.read_sql(
    '''
    SELECT *
    FROM roads
    ''',
    engine
)
# Out:
#                id               name     road_type  \
# 0      1413076062    Weustinkhoekweg       service
# 1         6654669    Weustinkhoekweg  unclassified
# 2       302682014                NaN      cycleway
# 3       272547407        Weustinkweg       service
# 4       272547406        Weustinkweg       service
# ...           ...                ...           ...
# 24375     6659447  Oldenzaalsestraat       primary
# 24376   541950842  Oldenzaalsestraat       primary
# 24377     6657565      Wiggersbosweg  unclassified
# 24378     6659423   Enschedesestraat       primary
# 24379     6659442   Enschedesestraat       primary
#
#                                                 geometry
# 0      0102000020E6100000020000004B033FAA61871B40E258...
# 1      0102000020E610000016000000AA42F82CFB8E1B405E4C...
# 2      0102000020E61000000200000018DAEF3FE8871B404B11...
# 3      0102000020E61000000A000000863AAC70CB871B406880...
# 4      0102000020E61000000400000015BBC7E3B3861B408D01...
# ...
