# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(
    'postgresql+psycopg://postgres:postgres@db:5432/mobility'
)

table = pd.read_sql(
    '''
    SELECT *
    FROM roads
    ''',
    engine
)

table['road_type'].unique()
# Out:
# <StringArray>
# [       'service',   'unclassified',       'cycleway',    'residential',
#            'path',          'track',        'footway',       'tertiary',
#       'secondary',  'tertiary_link',  'living_street',         'busway',
#  'secondary_link',          'steps',          'trunk',      'bridleway',
#        'motorway',  'motorway_link',     'trunk_link',   'construction',
#        'platform',        'primary',     'pedestrian',   'primary_link',
#        'proposed']
# Length: 25, dtype: str
