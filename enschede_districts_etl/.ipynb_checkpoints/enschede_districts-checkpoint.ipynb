# %% [markdown]
# # Enschede, the Netherlands

# %%
import requests
import pandas as pd
import geopandas as gpd
from pprint import pprint
import osmnx

# %% [markdown]
# ## Creating the Enschede Boundary GeoDataFrame
# ### Retrieving the PDOK Municipal Boundaries Dataset

# %%
root = 'https://api.pdok.nl/kadaster/bestuurlijkegebieden/ogc/v1'
landing = requests.get(root).json()

collections_url = next(
    link['href']
    for link in landing['links']
    if link['rel'] == 'data' and link['type'] == 'application/json'
)

collections = requests.get(collections_url).json()

municipalities_collection = next(
    collection
    for collection in collections['collections']
    if collection['id'] == 'gemeentegebied'
)

items_url = next(
    link['href']
    for link in municipalities_collection['links']
    if link['rel'] == 'items' and link['type'] == 'application/geo+json'
)

# %% [markdown]
# ### Building the GeoDataFrame

# %%
pages = requests.get(items_url).json()
gdfs = []

while True:

    gdf = gpd.GeoDataFrame.from_features(pages['features'], crs='EPSG:28992')
    gdfs.append(gdf)

    next_url = next((
        link['href']
        for link in pages['links']
        if link['rel'] == 'next'
    ), None)

    if next_url is None:
        break

    pages = requests.get(next_url).json()

cities = pd.concat(gdfs, ignore_index=True)

# %% [markdown]
# ### Inspecting the GeoDataFrame

# %%
cities.shape
# Out:
# (342, 6)

# %%
cities.head()
# Out:
#                                             geometry  code identificatie  \
# 0  MULTIPOLYGON (((5.266 51.739, 5.267 51.739, 5....  0263        GM0263
# 1  MULTIPOLYGON (((4.717 52.704, 4.717 52.704, 4....  0441        GM0441
# 2  MULTIPOLYGON (((5.696 50.755, 5.697 50.755, 5....  1903        GM1903
# 3  MULTIPOLYGON (((6.102 52.465, 6.102 52.464, 6....  0193        GM0193
# 4  MULTIPOLYGON (((5.857 51.029, 5.859 51.029, 5....  1711        GM1711
#
#   ligt_in_provincie_code ligt_in_provincie_naam               naam
# 0                     25             Gelderland          Maasdriel
# 1                     27          Noord-Holland            Schagen
# 2                     31                Limburg  Eijsden-Margraten
# 3                     23             Overijssel             Zwolle
# 4                     31                Limburg      Echt-Susteren

# %% [markdown]
# ### Cleaning the GeoDataFrame

# %%
enschede = cities[cities['naam'] == 'Enschede']

enschede = enschede[['naam', 'geometry']]
enschede = enschede.rename(columns={
    'naam': 'name'
})

# %% [markdown]
# ## Creating the Enschede Districts GeoDataFrame
# ### Retrieving the PDOK CBS Area Formats Dataset

# %%
root = 'https://api.pdok.nl/cbs/gebiedsindelingen/ogc/v1'
landing = requests.get(root).json()

collections_url = next(
    link['href']
    for link in landing['links']
    if link['rel'] == 'data' and link['type'] == 'application/json'
)

collections = requests.get(collections_url).json()

municipalities_collection = next(
    collection
    for collection in collections['collections']
    if collection['id'] == 'wijk_niet_gegeneraliseerd'
)

items_url = next(
    link['href']
    for link in municipalities_collection['links']
    if link['rel'] == 'items' and link['type'] == 'application/geo+json'
)

# %% [markdown]
# ### Building the GeoDataFrame

# %%
pages = requests.get(items_url).json()
gdfs = []

while True:

    feature_2025 = [
        feature
        for feature in pages['features']
        if feature['properties']['jaarcode'] == 2025
    ]

    if feature_2025:
        gdf = gpd.GeoDataFrame.from_features(feature_2025, crs='EPSG:28992')
        gdfs.append(gdf)

    next_url = next((
        link['href']
        for link in pages['links']
        if link['rel'] == 'next'
    ), None)

    if next_url is None:
        break

    pages = requests.get(next_url).json()

neighbourhoods = pd.concat(gdfs, ignore_index=True)

# %% [markdown]
# ### Inspecting the GeoDataFrame

# %%
neighbourhoods.shape
# Out:
# (3423, 10)

# %%
cities.head()
# Out:
#         name                                           geometry
# 82  Enschede  MULTIPOLYGON (((6.806 52.167, 6.806 52.167, 6....

# %% [markdown]
# ### Filtering for Enschede Districts

# %%
neighbourhoods = neighbourhoods.reset_index()

enschede_districts = gpd.overlay(neighbourhoods, enschede, how='intersection')
enschede_districts['area'] = enschede_districts.area

enschede_districts = enschede_districts.sort_values('area').drop_duplicates('index', keep='last')

# %%
n = neighbourhoods[neighbourhoods.intersects(enschede.union_all())]["index"].nunique()
print(n)
# Out:
# 21

# %%
neighbourhoods[neighbourhoods['geometry'].within(enschede['geometry'].iloc[0])]
# Out:
#       index                                           geometry  \
# 224     224  MULTIPOLYGON (((6.906 52.194, 6.909 52.192, 6....
# 532     532  MULTIPOLYGON (((6.917 52.225, 6.914 52.225, 6....
# 1494   1494  MULTIPOLYGON (((6.939 52.217, 6.939 52.214, 6....
# 1789   1789  MULTIPOLYGON (((6.88 52.201, 6.874 52.201, 6.8...
# 2125   2125  MULTIPOLYGON (((6.911 52.217, 6.909 52.214, 6....
# 2489   2489  MULTIPOLYGON (((6.859 52.225, 6.845 52.234, 6....
#
#                  einddatum gm_code    id  jaarcode    jrstatcode rubriek  \
# 224   2025-12-31T00:00:00Z  GM0153   226      2025  2025WK015306    wijk
# 532   2025-12-31T00:00:00Z  GM0153   541      2025  2025WK015305    wijk
# 1494  2025-12-31T00:00:00Z  GM0153  1536      2025  2025WK015301    wijk
# 1789  2025-12-31T00:00:00Z  GM0153  1835      2025  2025WK015302    wijk
# 2125  2025-12-31T00:00:00Z  GM0153  2181      2025  2025WK015300    wijk
# 2489  2025-12-31T00:00:00Z  GM0153  2552      2025  2025WK015303    wijk
#
#                 startdatum  statcode                        statnaam
# 224   2025-01-01T00:00:00Z  WK015306           Wijk 06 Enschede-Zuid
# 532   2025-01-01T00:00:00Z  WK015305     Wijk 05 Ribbelt - Stokhorst
# 1494  2025-01-01T00:00:00Z  WK015301        Wijk 01 Hogeland - Velve
# 1789  2025-01-01T00:00:00Z  WK015302   Wijk 02 Boswinkel - Stadsveld
# 2125  2025-01-01T00:00:00Z  WK015300      Wijk 00 Binnensingelgebied
# 2489  2025-01-01T00:00:00Z  WK015303  Wijk 03 Twekkelerveld - T.H.T.
